# %%
print("hello world")
# Out:
# hello world

# %%
x = 10                   # int
salary = 45000.50        # float
is_active = True         # boolean
skills = ["SQL", "Python", "AWS"]   # list

print(x, salary, is_active, skills)
# Out:
# 10 45000.5 True ['SQL', 'Python', 'AWS']

# %%
age = 28

if age > 25:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Eligible

# %%
name = "Akriti"
experience = 8
print(name, experience)
# Out:
# Akriti 8

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Akriti"))
# Out:
# Hello, Akriti!

# %%
for i in range(1, 6):
    print("Number:", i)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5

# %%
skills = ["SQL", "Python", "AWS"]
for s in skills:
    print(s)
# Out:
# SQL
# Python
# AWS

# %%
def annual_salary(monthly_salary):
    return monthly_salary * 12

print(annual_salary(50000))
# Out:
# 600000

# %%
def even_odd(num):
    if(num%2)==0:
        return ("even")
    else:
        return ("odd")

print(even_odd(5))
# Out:
# odd

# %%
def cnt_list(lst):
    cnt=0
    for i in(lst):
        if(i>50):
            cnt=cnt+1
    return cnt
print(cnt_list([10,55,23,85,7]))
# Out:
# 2

# %%
sample={
    "name":"john",
"place":"faridabad",
"field":"IT",
"salary":58000
}
import json
with open("profile.json","w")as f:
    json.dump(sample,f)

# %%
with open("profile.json","r") as f:
    data=json.load(f)
    print(data)
# Out:
# {'name': 'john', 'place': 'faridabad', 'field': 'IT', 'salary': 58000}

# %%
with open("employees.csv", "w") as f:
    f.write("id,name,salary\n")
    f.write("1,Riya,50000\n")
    f.write("2,Amit,60000\n")

# %%
import csv

with open("employees.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'salary']
# ['1', 'Riya', '50000']
# ['2', 'Amit', '60000']

# %%
import csv
with open("employees.csv") as f:
    reader=csv.DictReader(f)
    for i in reader:
        if int(i["salary"])>55000:
            print (i["name"])
# Out:
# Amit
