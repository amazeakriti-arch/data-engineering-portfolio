# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd
df=pd.read_csv("employees.csv")
print(df)
# Out:
#    id  name  salary
# 0   1  Riya   50000
# 1   2  Amit   60000

# %%
import pandas as pd
df=pd.read_csv("employees.csv")
df
# Out:
#    id  name  salary
# 0   1  Riya   50000
# 1   2  Amit   60000

# %%
df.head()      # first 5 rows
df.tail()      # last 5 rows
df.info()      # schema + nulls
df.describe()  # statistics (numeric columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2 non-null      int64
#  1   name    2 non-null      object
#  2   salary  2 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 180.0+ bytes
#              id        salary
# count  2.000000      2.000000
# mean   1.500000  55000.000000
# std    0.707107   7071.067812
# min    1.000000  50000.000000
# 25%    1.250000  52500.000000
# 50%    1.500000  55000.000000
# 75%    1.750000  57500.000000
# max    2.000000  60000.000000

# %%
df.head()
# Out:
#    id  name  salary
# 0   1  Riya   50000
# 1   2  Amit   60000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2 non-null      int64
#  1   name    2 non-null      object
#  2   salary  2 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 180.0+ bytes

# %%
df.describe()
# Out:
#              id        salary
# count  2.000000      2.000000
# mean   1.500000  55000.000000
# std    0.707107   7071.067812
# min    1.000000  50000.000000
# 25%    1.250000  52500.000000
# 50%    1.500000  55000.000000
# 75%    1.750000  57500.000000
# max    2.000000  60000.000000

# %%
df["Department"]=["Data","IT"]
df["Experience"]=[3,5]
df["Location"]=["Chennai","Pune"]

# %%
df
# Out:
#    id  name  salary Department  Experience Location
# 0   1  Riya   50000       Data           3  Chennai
# 1   2  Amit   60000         IT           5     Pune

# %%
df.loc[len(df)]=[3,"Sneha",55000,"HR",2,"Pune"]

# %%
df
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  Chennai
# 1   2   Amit   60000         IT           5     Pune
# 2   3  Sneha   55000         HR           2     Pune

# %%
len(df)
# Out:
# 3

# %%
df.loc[len(df)]=[4,"Kiara",70000,"HR",5,"Delhi"]

# %%
df.to_csv("employees.csv",index=False)

# %%
df.groupby("Department")["salary"].mean()
# Out:
# Department
# Data    50000.0
# HR      62500.0
# IT      60000.0
# Name: salary, dtype: float64

# %%
df
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  Chennai
# 1   2   Amit   60000         IT           5     Pune
# 2   3  Sneha   55000         HR           2     Pune
# 3   4  Kiara   70000         HR           5    Delhi

# %%
df.loc[len(df)]=[5,"Meena",73000,"CS",6,"Nagpur"]

# %%
df.loc[len(df)]=[6,"Juhi",80000,"Data",6,"Delhi"]

# %%
df
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  Chennai
# 1   2   Amit   60000         IT           5     Pune
# 2   3  Sneha   55000         HR           2     Pune
# 3   4  Kiara   70000         HR           5    Delhi
# 4   5  Meena   73000         CS           6   Nagpur
# 5   6   Juhi   80000       Data           6    Delhi

# %%
import pandas as pd
df=pd.read_csv("employees.csv")
df["salary"]=df["salary"].astype(int)

# %%
def exp_level(exp):
    if exp<2:
        return "Junior"
    elif exp<=5 :
        return "Mid"
    else:
        return "Senior"

df["Experience_level"]=df["Experience"].apply(exp_level)

# %%
df
# Out:
#    id   name  salary Department  Experience Location Experience_level
# 0   1   Riya   50000       Data           3  CHENNAI              Mid
# 1   2   Amit   60000         IT           5     PUNE              Mid
# 2   3  Sneha   55000         HR           2     PUNE              Mid
# 3   4  Kiara   85000         HR           5    DELHI              Mid
# 4   5  Meena   73000         CS           6   NAGPUR           Senior
# 5   6   Juhi   80000       Data           6    DELHI           Senior

# %%
df["salary_lakhs"]=df["salary"]/100000

# %%
df
# Out:
#    id   name  salary Department  Experience Location Experience_level  \
# 0   1   Riya   50000       Data           3  CHENNAI              Mid
# 1   2   Amit   60000         IT           5     PUNE              Mid
# 2   3  Sneha   55000         HR           2     PUNE              Mid
# 3   4  Kiara   85000         HR           5    DELHI              Mid
# 4   5  Meena   73000         CS           6   NAGPUR           Senior
# 5   6   Juhi   80000       Data           6    DELHI           Senior
#
#    salary_lakhs
# 0          0.50
# 1          0.60
# 2          0.55
# 3          0.85
# 4          0.73
# 5          0.80

# %%
df.head()
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  Chennai
# 1   2   Amit   60000         IT           5     Pune
# 2   3  Sneha   55000         HR           2     Pune
# 3   4  Kiara   70000         HR           5    Delhi
# 4   5  Meena   73000         CS           6   Nagpur

# %%
df.columns
# Out:
# Index(['id', 'name', 'salary', 'Department', 'Experience', 'Location'], dtype='object')

# %%
df.index
# Out:
# Index([0, 1, 2, 3, 4, 5], dtype='int64')

# %%
df["Location"]
# Out:
# 0    Chennai
# 1       Pune
# 2       Pune
# 3      Delhi
# 4     Nagpur
# 5      Delhi
# Name: Location, dtype: object

# %%
set(df["Location"])
# Out:
# {'Chennai', 'Delhi', 'Nagpur', 'Pune'}

# %%
df.iloc[0]
# Out:
# id                  1
# name             Riya
# salary          50000
# Department       Data
# Experience          3
# Location      Chennai
# Name: 0, dtype: object

# %%
df.iloc[1,5]
# Out:
# 'Pune'

# %%
df.iloc[1]["Location"]
# Out:
# 'Pune'

# %%
df[df["Department"]=="HR"]
# Out:
#    id   name  salary Department  Experience Location
# 2   3  Sneha   55000         HR           2     Pune
# 3   4  Kiara   70000         HR           5    Delhi

# %%
df[(df["Department"]=="HR") & (df["Location"]=="Delhi")]
# Out:
#    id   name  salary Department  Experience Location
# 3   4  Kiara   70000         HR           5    Delhi

# %%
df[(df["Department"]=="HR") | (df["Location"]=="Delhi")]
# Out:
#    id   name  salary Department  Experience Location
# 2   3  Sneha   55000         HR           2     Pune
# 3   4  Kiara   70000         HR           5    Delhi
# 5   6   Juhi   80000       Data           6    Delhi

# %%
df[df["name"].str.startswith("J")]
# Out:
#    id  name  salary Department  Experience Location
# 5   6  Juhi   80000       Data           6    Delhi

# %%
df[df["Location"].isin(["Pune","Nagpur"])]
# Out:
#    id   name  salary Department  Experience Location
# 1   2   Amit   60000         IT           5     Pune
# 2   3  Sneha   55000         HR           2     Pune
# 4   5  Meena   73000         CS           6   Nagpur

# %%
df[~df["Location"].isin(["Pune","Nagpur"])]
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  Chennai
# 3   4  Kiara   70000         HR           5    Delhi
# 5   6   Juhi   80000       Data           6    Delhi

# %%
df.loc[df["name"]=="Kiara"]
# Out:
#    id   name  salary Department  Experience Location
# 3   4  Kiara   70000         HR           5    Delhi

# %%
df.loc[df["name"]=="Kiara","salary"]=85000

# %%
df.loc[df["name"]=="Kiara"]
# Out:
#    id   name  salary Department  Experience Location
# 3   4  Kiara   85000         HR           5    Delhi

# %%
df["Location"]=df["Location"].str.upper()

# %%
df
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  CHENNAI
# 1   2   Amit   60000         IT           5     PUNE
# 2   3  Sneha   55000         HR           2     PUNE
# 3   4  Kiara   85000         HR           5    DELHI
# 4   5  Meena   73000         CS           6   NAGPUR
# 5   6   Juhi   80000       Data           6    DELHI

# %%
df["Location"]=df["Location"].str.lower()

# %%
df
# Out:
#    id   name  salary Department  Experience Location Experience_level  \
# 0   1   Riya   50000       Data           3  chennai              Mid
# 1   2   Amit   60000         IT           5     pune              Mid
# 2   3  Sneha   55000         HR           2     pune              Mid
# 3   4  Kiara   85000         HR           5    delhi              Mid
# 4   5  Meena   73000         CS           6   nagpur           Senior
# 5   6   Juhi   80000       Data           6    delhi           Senior
#
#    salary_lakhs
# 0          0.50
# 1          0.60
# 2          0.55
# 3          0.85
# 4          0.73
# 5          0.80

# %%
df.to_csv("transformed_emp.csv",index=False)

# %%
transformed_emp

# %%
df.dropna()
# Out:
#    id   name  salary Department  Experience Location
# 0   1   Riya   50000       Data           3  CHENNAI
# 1   2   Amit   60000         IT           5     PUNE
# 2   3  Sneha   55000         HR           2     PUNE
# 3   4  Kiara   85000         HR           5    DELHI
# 4   5  Meena   73000         CS           6   NAGPUR
# 5   6   Juhi   80000       Data           6    DELHI

# %%
df["Location"].value_counts()
# Out:
# Location
# PUNE       2
# DELHI      2
# CHENNAI    1
# NAGPUR     1
# Name: count, dtype: int64

# %%
df.sort_values("salary",ascending=False)
# Out:
#    id   name  salary Department  Experience Location
# 3   4  Kiara   85000         HR           5    DELHI
# 5   6   Juhi   80000       Data           6    DELHI
# 4   5  Meena   73000         CS           6   NAGPUR
# 1   2   Amit   60000         IT           5     PUNE
# 2   3  Sneha   55000         HR           2     PUNE
# 0   1   Riya   50000       Data           3  CHENNAI

# %%
high_paid=df[df["salary"]>60000]

# %%
high_paid
# Out:
#    id   name  salary Department  Experience Location Experience_level  \
# 3   4  Kiara   85000         HR           5    DELHI              Mid
# 4   5  Meena   73000         CS           6   NAGPUR           Senior
# 5   6   Juhi   80000       Data           6    DELHI           Senior
#
#    salary_lakhs
# 3          0.85
# 4          0.73
# 5          0.80

# %%
data_team=df[df["Department"]=="HR"]

# %%
data_team
# Out:
#    id   name  salary Department  Experience Location Experience_level  \
# 2   3  Sneha   55000         HR           2     PUNE              Mid
# 3   4  Kiara   85000         HR           5    DELHI              Mid
#
#    salary_lakhs
# 2          0.55
# 3          0.85

# %%
data_team.to_csv("employees_data_team.csv",index=False)
